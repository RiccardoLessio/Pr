# %%
import matplotlib.pyplot as plt

from matplotlib.font_manager import FontProperties
#size
plt.rcParams["figure.figsize"] = (8, 5)

#font
font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')
font.set_style('italic')
#stileplot
#plt.style.use('seaborn-v0_8-notebook')
#plt.style.use('default')
plt.style.use('seaborn-v0_8-whitegrid')
#titolo
plt.suptitle("Payoff contratto forward (Short Position)",fontsize=14,style='italic')#,weight='bold'

#nomi assi
plt.xlabel("Prezzo Sottostante", fontsize=12,style='italic')
plt.ylabel("Profitto", fontsize=12,style='italic')

#colore nuemero assi
plt.xticks(color="black") #w=white b=blu
plt.yticks(color="black") #w=white b=blu

#griglia
plt.grid(True)

#lunghezza assi
plt.axis ((-5,20,-20,20))

#figure
plt.plot([10],[0],"go", color="black") #punto1

plt.plot([19.8],[0],">", color="black") #freccia
plt.plot([0],[19.5],"^", color="black") #freccia
plt.plot([0,20],[+15,-15], color="black", linewidth=2)#linea
plt.plot([0,0],[-20,20], color="black", linewidth=1.07)#linea
plt.plot([-5,20],[0,0], color="black", linewidth=1.07)#linea
plt.text(9.7, +1.8, r'K',fontsize=16,style='italic')#testo


plt.text(0.4, 18, r'π',fontsize=16,style='italic')#testo
plt.text(19, 0.9, r'St',fontsize=16,style='italic')#testo

plt.show()
# Out:
# <ipython-input-1-9a9304f86157>:34: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "go" (-> color='g'). The keyword argument will take precedence.
#   plt.plot([10],[0],"go", color="black") #punto1
